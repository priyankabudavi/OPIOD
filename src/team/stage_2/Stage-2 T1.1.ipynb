# %% [markdown]
# ## Project Stage - II (Data Modeling)
#
#
# ### Goals
#
# The goal of Stage II is to develop the data for modeling and comparative analysis. Here you will be graphically comparing how different states are doing with respect to opioid mortality rate. And you will be also analysing county based information for different states in the US.
#
# Dataset:
#
# We are going to use historical dataset here for opioid related mortality from 1999 -2019 for different causes of death. Extracted from:
# https://wonder.cdc.gov/wonder/help/ucd.html#Drug/Alcohol%20Induced%20Causes
#
# File: ./data/1999-2020_Drug_Overdose_By_Category.csv
#
# * T1.1 Import the historical data from: ./data/1999-2020_Drug_Overdose_By_Category.xls (10 pts)

# %%
import pandas as pd
src=pd.read_csv("../../../data/stage_2/1999-2020_Drug_Overdose_By_Category.csv")
src.head()
# Out:
#      Table Names  Notes                County  County Code  Year  Year Code  \
# 0  1999-2000.txt    NaN  Jefferson County, AL         1073  1999       1999
# 1  1999-2000.txt    NaN  Jefferson County, AL         1073  2000       2000
# 2  1999-2000.txt    NaN  Jefferson County, AL         1073  2000       2000
# 3  1999-2000.txt    NaN  Jefferson County, AL         1073  2000       2000
# 4  1999-2000.txt    NaN     Mobile County, AL         1097  1999       1999
#
#                           Drug/Alcohol Induced Cause  \
# 0  Drug poisonings (overdose) Unintentional (X40-...
# 1  Drug poisonings (overdose) Unintentional (X40-...
# 2       Drug poisonings (overdose) Suicide (X60-X64)
# 3                      All other drug-induced causes
# 4  Drug poisonings (overdose) Unintentional (X40-...
#
#   Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate
# 0                              D1      25      662845         3.8
# 1                              D1      30      662047         4.5
# 2                              D2      14      662047  Unreliable
# 3                              D9      20      662047         3.0
# 4                              D1      20      399323         5.0

# %%
src=src.fillna(0)

# %% [markdown]
# ##### T.1.1.1 Normalize the mortality by population
#
# * Here we normalise the deaths per 100,000.

# %%
src["Norm_Deaths"] = round((src["Deaths"]/src["Population"])*100000)
src.head()
# Out:
#      Table Names  Notes                County  County Code  Year  Year Code  \
# 0  1999-2000.txt    0.0  Jefferson County, AL         1073  1999       1999
# 1  1999-2000.txt    0.0  Jefferson County, AL         1073  2000       2000
# 2  1999-2000.txt    0.0  Jefferson County, AL         1073  2000       2000
# 3  1999-2000.txt    0.0  Jefferson County, AL         1073  2000       2000
# 4  1999-2000.txt    0.0     Mobile County, AL         1097  1999       1999
#
#                           Drug/Alcohol Induced Cause  \
# 0  Drug poisonings (overdose) Unintentional (X40-...
# 1  Drug poisonings (overdose) Unintentional (X40-...
# 2       Drug poisonings (overdose) Suicide (X60-X64)
# 3                      All other drug-induced causes
# 4  Drug poisonings (overdose) Unintentional (X40-...
#
#   Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  Norm_Deaths
# 0                              D1      25      662845         3.8          4.0
# 1                              D1      30      662047         4.5          5.0
# 2                              D2      14      662047  Unreliable          2.0
# 3                              D9      20      662047         3.0          3.0
# 4                              D1      20      399323         5.0          5.0

# %% [markdown]
# ###### Calculate mean for states and then mean for US per year
#
# * The states are abreviated in the column county, which first needs to be split as a new column.
# * Then to calculate the mean for states we groupby states.

# %%
newdf=src["County"].str.split(",", n = 1, expand = True)
src['State']=newdf[1]
src['County Name']=newdf[0]
src.drop(columns =["County"], inplace = True)
src.head()
# Out:
#      Table Names  Notes  County Code  Year  Year Code  \
# 0  1999-2000.txt    0.0         1073  1999       1999
# 1  1999-2000.txt    0.0         1073  2000       2000
# 2  1999-2000.txt    0.0         1073  2000       2000
# 3  1999-2000.txt    0.0         1073  2000       2000
# 4  1999-2000.txt    0.0         1097  1999       1999
#
#                           Drug/Alcohol Induced Cause  \
# 0  Drug poisonings (overdose) Unintentional (X40-...
# 1  Drug poisonings (overdose) Unintentional (X40-...
# 2       Drug poisonings (overdose) Suicide (X60-X64)
# 3                      All other drug-induced causes
# 4  Drug poisonings (overdose) Unintentional (X40-...
#
#   Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  \
# 0                              D1      25      662845         3.8
# 1                              D1      30      662047         4.5
# 2                              D2      14      662047  Unreliable
# 3                              D9      20      662047         3.0
# 4                              D1      20      399323         5.0
#
#    Norm_Deaths State       County Name
# 0          4.0    AL  Jefferson County
# 1          5.0    AL  Jefferson County
# 2          2.0    AL  Jefferson County
# 3          3.0    AL  Jefferson County
# 4          5.0    AL     Mobile County

# %% [markdown]
# * Once we split the state name into a seperate column, we then groupby the state to calculate mean rate of normalised deaths for
# states.

# %%
#displaying mean deaths across each state
statedf=src.groupby(['State']).mean() #calculates the mean of all the columns
statedf=statedf[['Norm_Deaths']] # since we only want the mortality rate, we will only consider Norm_death column
statedf
# Out:
#        Norm_Deaths
# State
#  AK            inf
#  AL     875.530312
#  AR    1046.926143
#  AZ     307.579247
#  CA     269.309476
#  CO     523.740741
#  CT     257.225806
#  DC     171.618557
#  DE     312.692737
#  FL     427.895559
#  GA     779.092676
#  HI     273.889401
#  IA    1023.247005
#  ID     699.125847
#  IL     798.731970
#  IN     707.949146
#  KS    1086.818142
#  KY     900.316234
#  LA     737.560921
#  MA     270.716940
#  MD     391.205616
#  ME     631.204842
#  MI     645.651214
#  MN     810.868845
#  MO     931.411365
#  MS    1003.404197
#  MT     958.557983
#  NC     624.643619
#  ND    1131.522445
#  NE    1106.513375
#  NH     452.425428
#  NJ     291.333068
#  NM     548.143363
#  NV     581.021739
#  NY     457.320528
#  OH     583.993468
#  OK     914.709350
#  OR     541.962770
#  PA     539.292746
#  RI     379.784861
#  SC     632.494404
#  SD    1042.959581
#  TN     801.632068
#  TX     774.431511
#  UT     456.620327
#  VA     822.476941
#  VT     696.250689
#  WA     427.907248
#  WI     683.199416
#  WV     909.298630
#  WY     728.023679

# %% [markdown]
# * <b>From the above generated results we can see the mean of deaths across all 50 states.</b>
# * Also, we can see that for state AK there is an infinity value, so now we go ahead and check if the dataframe consists of infinity value or is the mean infinite.

# %%
#checking for infity value
import numpy as np
srcd=src['Norm_Deaths']
r=np.isfinite(srcd)
r[~r] # ~r is used to display the false values-which indicates that there are some infinity values in the dataframe
# Out:
# 1219    False
# Name: Norm_Deaths, dtype: bool

# %% [markdown]
# * From the above generated result we can see there is some infinity value at index 1219.
# * We check by displaying the entire row and then drop this column.

# %%
#displaying the column that needs to be dropped to check what is giving inf value as the result
dropcol=src.iloc[1219]
dropcol
# Out:
# Table Names                                                    2017-2020.txt
# Notes                                                                    0.0
# County Code                                                             2261
# Year                                                                    2020
# Year Code                                                               2020
# Drug/Alcohol Induced Cause         All other non-drug and non-alcohol causes
# Drug/Alcohol Induced Cause Code                                           O9
# Deaths                                                                    54
# Population                                                                 0
# Crude Rate                                                               0.0
# Norm_Deaths                                                              inf
# State                                                                     AK
# County Name                                       Valdez-Cordova Census Area
# Name: 1219, dtype: object

# %% [markdown]
# * We can see that the population column contains 0 values, so when we Normalise the population(which divides the deaths by population) we get inf value for the Norm_deaths column, so we need to drop it.

# %%
src=src.drop([1219])
src
# Out:
#          Table Names  Notes  County Code  Year  Year Code  \
# 0      1999-2000.txt    0.0         1073  1999       1999
# 1      1999-2000.txt    0.0         1073  2000       2000
# 2      1999-2000.txt    0.0         1073  2000       2000
# 3      1999-2000.txt    0.0         1073  2000       2000
# 4      1999-2000.txt    0.0         1097  1999       1999
# ...              ...    ...          ...   ...        ...
# 90902  2005-2009.txt    0.0        56043  2008       2008
# 90903  2005-2009.txt    0.0        56045  2005       2005
# 90904  2005-2009.txt    0.0        56045  2006       2006
# 90905  2005-2009.txt    0.0        56045  2007       2007
# 90906  2005-2009.txt    0.0        56045  2008       2008
#
#                               Drug/Alcohol Induced Cause  \
# 0      Drug poisonings (overdose) Unintentional (X40-...
# 1      Drug poisonings (overdose) Unintentional (X40-...
# 2           Drug poisonings (overdose) Suicide (X60-X64)
# 3                          All other drug-induced causes
# 4      Drug poisonings (overdose) Unintentional (X40-...
# ...                                                  ...
# 90902          All other non-drug and non-alcohol causes
# 90903          All other non-drug and non-alcohol causes
# 90904          All other non-drug and non-alcohol causes
# 90905          All other non-drug and non-alcohol causes
# 90906          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  \
# 0                                  D1      25      662845         3.8
# 1                                  D1      30      662047         4.5
# 2                                  D2      14      662047  Unreliable
# 3                                  D9      20      662047         3.0
# 4                                  D1      20      399323         5.0
# ...                               ...     ...         ...         ...
# 90902                              O9      89        8229      1081.5
# 90903                              O9      71        6594      1076.7
# 90904                              O9      70        6717      1042.1
# 90905                              O9      79        7033      1123.3
# 90906                              O9      61        7133       855.2
#
#        Norm_Deaths State       County Name
# 0              4.0    AL  Jefferson County
# 1              5.0    AL  Jefferson County
# 2              2.0    AL  Jefferson County
# 3              3.0    AL  Jefferson County
# 4              5.0    AL     Mobile County
# ...            ...   ...               ...
# 90902       1082.0    WY   Washakie County
# 90903       1077.0    WY     Weston County
# 90904       1042.0    WY     Weston County
# 90905       1123.0    WY     Weston County
# 90906        855.0    WY     Weston County
#
# [90906 rows x 13 columns]

# %%
#now we calculate the mean again 
#displaying mean deaths across each state
statedf_final=src.groupby(['State'],as_index=False).mean() #calculates the mean of all the columns
statedf_final=statedf_final[['State','Norm_Deaths']] # since we only want the mortality rate, we will only consider Norm_death column
statedf_final
# Out:
#    State  Norm_Deaths
# 0     AK   468.255537
# 1     AL   875.530312
# 2     AR  1046.926143
# 3     AZ   307.579247
# 4     CA   269.309476
# 5     CO   523.740741
# 6     CT   257.225806
# 7     DC   171.618557
# 8     DE   312.692737
# 9     FL   427.895559
# 10    GA   779.092676
# 11    HI   273.889401
# 12    IA  1023.247005
# 13    ID   699.125847
# 14    IL   798.731970
# 15    IN   707.949146
# 16    KS  1086.818142
# 17    KY   900.316234
# 18    LA   737.560921
# 19    MA   270.716940
# 20    MD   391.205616
# 21    ME   631.204842
# 22    MI   645.651214
# 23    MN   810.868845
# 24    MO   931.411365
# 25    MS  1003.404197
# 26    MT   958.557983
# 27    NC   624.643619
# 28    ND  1131.522445
# 29    NE  1106.513375
# 30    NH   452.425428
# 31    NJ   291.333068
# 32    NM   548.143363
# 33    NV   581.021739
# 34    NY   457.320528
# 35    OH   583.993468
# 36    OK   914.709350
# 37    OR   541.962770
# 38    PA   539.292746
# 39    RI   379.784861
# 40    SC   632.494404
# 41    SD  1042.959581
# 42    TN   801.632068
# 43    TX   774.431511
# 44    UT   456.620327
# 45    VA   822.476941
# 46    VT   696.250689
# 47    WA   427.907248
# 48    WI   683.199416
# 49    WV   909.298630
# 50    WY   728.023679

# %% [markdown]
# * After we drop the infinity value, we can see that the statedf now contains the mean death values across all the 50 states.

# %% [markdown]
# ##### Next, we calculate the mean for US per year
#
# * Here,we groupby both the year and the State, because it is important to understand,how the mortality rate varied accross different states for different years.

# %%
yeardf=src.groupby(['Year','State'],as_index=False).mean()
yeardf=yeardf[['Year','State','Norm_Deaths']]
yeardf
# Out:
#       Year State  Norm_Deaths
# 0     1999    AK     5.000000
# 1     1999    AL     4.500000
# 2     1999    AZ     3.857143
# 3     1999    CA     5.666667
# 4     1999    CO     4.750000
# ...    ...   ...          ...
# 1098  2020    VT   597.720000
# 1099  2020    WA   403.531250
# 1100  2020    WI   661.876923
# 1101  2020    WV   874.806452
# 1102  2020    WY   796.375000
#
# [1103 rows x 3 columns]

# %% [markdown]
# * The above dataframe displays the data for each year.
# * Norm_Deaths column displays the mean death rate across each state.

# %%
yeardf=yeardf.groupby(['Year'],as_index=False)['Norm_Deaths'].mean()
yeardf
# Out:
#     Year  Norm_Deaths
# 0   1999     4.947826
# 1   2000     4.980769
# 2   2001   805.590618
# 3   2002   804.939975
# 4   2003   778.231221
# 5   2004   739.761790
# 6   2005   742.323179
# 7   2006   719.278977
# 8   2007   708.844099
# 9   2008   712.164569
# 10  2009   696.954400
# 11  2010   691.571268
# 12  2011   689.866445
# 13  2012   693.710631
# 14  2013   694.250109
# 15  2014   691.817889
# 16  2015   697.858107
# 17  2016   679.104658
# 18  2017   683.899637
# 19  2018   687.554837
# 20  2019   685.513806
# 21  2020   750.034231

# %% [markdown]
# * Next,we calculate the Normalised death rate accross different years by grouping different years.

# %% [markdown]
# ### Plot a line graph

# %%
import plotly.express as px
fig=px.line(statedf_final,x=statedf_final['State'],y=statedf_final['Norm_Deaths'],markers=True,title="Opiod Mortality across different states")
fig.write_image("stageII_images/line plot-states.png")
fig.show("png")

# %% [markdown]
# #### Discuss why there was a peak
# * In plot-1 the highest mortality rate is across state ND and the mean death rate is 1131.521.
# * Here, we hypothesise that the moratlity rates across each of the states maybe influenced by the population and hence as the population increases so does the mortality rate inceases.
# * The peaks could have also been due to the opiod dispensing rate.

# %%
import plotly.express as px
fig=px.line(yeardf, x=yeardf['Year'],y=yeardf['Norm_Deaths'],
            markers=True,title="Opiod Mortality rate across different years across US")
fig.write_image("stageII_images/line plot-years.png")
fig.show("png")

# %% [markdown]
# #### Discuss why there was a peak
# * In plot-2 the highest mortality rate was in the year 2001 with a mean death rate of 734.8614.
# * Also,we can observe form the graph that the opiod mortality rate is significantly fluctuating, there was a sudden spike in early 2000's and then the rates have been constatnt since then, this maybe because there is a lot of missing data for the years 1999 and 2000.
# * The peaks could have also been due to opiod dispensing rate.
#
# #### Research based on Google:
# * In 2020, 91,799 drug overdose deaths occurred in the United States. The age-adjusted rate of overdose deaths increased by 31% from 2019 (21.6 per 100,000) to 2020 (28.3 per 100,000).
# * Opioids—mainly synthetic opioids (other than methadone)—are currently the main driver of drug overdose deaths. 82.3% of opioid-involved overdose deaths involved synthetic opioids.
# * Opioids were involved in 68,630 overdose deaths in 2020 (74.8% of all drug overdose deaths).Drug overdose deaths involving psychostimulants such as methamphetamine are increasing with and without synthetic opioid involvement.
#
# * <b>From, both google and obtained results we can see that the opiod mortality rate spiked the most after 2001 due to drug overdose, which is propotional to the population growth.

# %% [markdown]
# References:
# * https://www.geeksforgeeks.org/check-if-dataframe-contains-infinity-in-python-pandas/
# * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
